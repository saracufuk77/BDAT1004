# %%
#Assignment 5 Part 1 section 1

import xml.etree.ElementTree as ET
tree = ET.parse('Festivals_and_Events_v9_fromArchivedb.xml')
root = tree.getroot()

for element in tree.getiterator():
    dict_keys={}
    if element.keys():
        for name, value in element.items():
            dict_keys[name]=value
        print (dict_keys)
n=0
while n<5:
    print('#{} node:'.format(n+1))  
    print(root[n].attrib)
    n+=1
# Out:
# {'timestamp': '20170213T195128,61Z', 'toplevelentries': '38481'}
# {'position': '1', 'unid': '85257EC200569F5985257F77006E019A', 'noteid': 'A8FE6', 'siblings': '38481'}
# {'columnnumber': '0', 'name': 'EventName'}
# {'columnnumber': '1', 'name': 'Area'}
# {'columnnumber': '2', 'name': 'CategoryList'}
# {'columnnumber': '3', 'name': 'PresentedByOrgName'}
# {'columnnumber': '4', 'name': 'Image'}
# {'columnnumber': '5', 'name': 'DateBeginShow'}
# {'columnnumber': '6', 'name': 'TimeBegin'}
# {'columnnumber': '7', 'name': 'DateEndShow'}
# {'columnnumber': '8', 'name': 'TimeEnd'}
# {'columnnumber': '9', 'name': 'Admission'}
# {'columnnumber': '10', 'name': 'LongDesc'}
# {'columnnumber': '11', 'name': 'OrgContactPhone'}
# {'columnnumber': '12', 'name': 'OrgContactExt'}
# {'columnnumber': '13', 'name': 'Location'}
# {'columnnumber': '14', 'name': 'Intersection'}
# {'columnnumber': '15', 'name': 'MapAddress'}
# {'columnnumber': '16', 'name': 'TTC'}
# ...

# %%
#Assignment 5 Part 1 section 2
import json
with open('edc_eventcal_APR.json') as data_file:
    data = json.load(data_file)
    
print ('User count:', len(data))

#print(type(data))

#for item in data:
 #   print(type(item))
    #print(item.get('calEvent'))
    #print(item.get('calEvent')[2].get('orgType'))

for item in data:
    for key,value in item.items():
        print(key)
        
print(data[-5:])
# Out:
# User count: 390
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# calEvent
# ...

# %%
#Assignment 5 Part 3

import sqlite3

conn = sqlite3.connect('group7.sqlite')
cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS Students')
cur.execute('CREATE TABLE Students (stu_name TEXT, stu_id INTEGER)')
cur.execute('DROP TABLE IF EXISTS Courses')
cur.execute('CREATE TABLE Courses (crs_name TEXT, crs_id INTEGER)')
cur.execute('DROP TABLE IF EXISTS Relation')
cur.execute('CREATE TABLE Relation (stu_id INTEGER, crs_id INTEGER)')
conn.commit()

cur.executemany("INSERT INTO Students (stu_name, stu_id) VALUES (?,?)",[("Ufuk", 1),("Cihat",2),("Abdulkadir",3),("Mehmet Ali",4)])
cur.executemany("INSERT INTO Courses (crs_name,crs_id) VALUES (?,?)",[("Data Manipulation",1000),("Information Encoding",1001),("System Architecture",1002),("Business Process",1003),("Programing", 1004),("Mathematics",1005)])
cur.executemany("INSERT INTO Relation (stu_id, crs_id) VALUES (?,?)",[(1,1004),(1,1005),(1,1000),(1,1002),(2,1004),(2,1003),(2,1001),(3,1003),(3,1000),(3,1002),(4,1000),(4,1004)])

conn.commit()

print("Students table:")            
cur.execute('SELECT stu_name, stu_id FROM Students')
for row in cur:
    print(row)

print("\nCourses table:")
cur.execute('SELECT crs_name, crs_id FROM Courses')
for row in cur:
    print(row)

print("\nRelations:")
cur.execute('SELECT Students.stu_id, Students.stu_name, Relation.crs_id, Courses.crs_name From Students JOIN Relation ON Students.stu_id=Relation.stu_id JOIN Courses ON Relation.crs_id=Courses.crs_id')
for row in cur:
    print(row)
    
conn.close()
# Out:
# Students table:
# ('Ufuk', 1)
# ('Cihat', 2)
# ('Abdulkadir', 3)
# ('Mehmet Ali', 4)
#
# Courses table:
# ('Data Manipulation', 1000)
# ('Information Encoding', 1001)
# ('System Architecture', 1002)
# ('Business Process', 1003)
# ('Programing', 1004)
# ('Mathematics', 1005)
#
# Relations:
# (1, 'Ufuk', 1000, 'Data Manipulation')
# (1, 'Ufuk', 1002, 'System Architecture')
# (1, 'Ufuk', 1004, 'Programing')
# (1, 'Ufuk', 1005, 'Mathematics')
# (2, 'Cihat', 1001, 'Information Encoding')
# (2, 'Cihat', 1003, 'Business Process')
# (2, 'Cihat', 1004, 'Programing')
# (3, 'Abdulkadir', 1000, 'Data Manipulation')
# (3, 'Abdulkadir', 1002, 'System Architecture')
# (3, 'Abdulkadir', 1003, 'Business Process')
# (4, 'Mehmet Ali', 1000, 'Data Manipulation')
# (4, 'Mehmet Ali', 1004, 'Programing')
